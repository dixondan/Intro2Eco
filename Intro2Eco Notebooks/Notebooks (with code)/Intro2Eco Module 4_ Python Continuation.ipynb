# %% [markdown]
# # Python is an always evolving language with new developments each day!

# %% [markdown]
# Hopefully, by now you feel like Neo!
#
# ![alt text](https://media.giphy.com/media/WSxm4Gq0Xv5fi/giphy.gif)

# %% [markdown]
# # Environments for working with Python locally

# %% [markdown]
# 1. Anaconda and Spyder / Jupyter notebooks
# https://www.anaconda.com/distribution/
#
# 2. PyCharm
# https://www.jetbrains.com/pycharm/

# %% [markdown]
# # Sources for debugging and finding code snippets

# %% [markdown]
# 1. Stack Overflow is where all computer scientists learn how to program!
# https://stackoverflow.com/questions/tagged/python
#
# 2. GIS stack exchange is for specific GIS questions on stack overflow
# https://gis.stackexchange.com/
#
# 3. DOCS!!!! Every good library has a docs page with examples and all the code https://pandas.pydata.org/pandas-docs/stable/index.html
# https://docs.scipy.org/doc/numpy/reference/

# %% [markdown]
# # Other links:

# %% [markdown]
# 1. A cool introduction to GDAL
# https://medium.com/planet-stories/a-gentle-introduction-to-gdal-part-1-a3253eb96082
#
# 2. Python programming course material https://automating-gis-processes.github.io/CSC18/course-info/course-info.html
#
# 3. Matplotlib tutorial https://jakevdp.github.io/mpl_tutorial/tutorial_pages/tut3.html
#
# 4. Google cloud platform -- setting up a Python environment https://cloud.google.com/python/setup
#
# 5. Remote sensing Python and R tutorial https://www.earthdatascience.org/courses/earth-analytics/multispectral-remote-sensing-data/vegetation-indices-NDVI-in-R/
#
# 6. Pandas tutorial https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/
#
# 7. Essential python tutorial w/ numpy http://cs231n.github.io/python-numpy-tutorial/
#
# 8. If you're into remote sensing, you should get into Google Earth Engine immediately!
# https://earthengine.google.com/
